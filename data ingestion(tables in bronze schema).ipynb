-- %%
%python
df=spark.read.csv("/Volumes/databricks_practice/bronze/raw_csv_files",header=True,inferSchema=True)
df.write.saveAsTable("databricks_practice.bronze.customer_ver2")

-- %%
%sql
create table databricks_practice.bronze.customer_ver3 as
select *,current_timestamp as ingestion_date  from read_files(
    "/Volumes/databricks_practice/bronze/raw_csv_files",
    format => 'csv'
);
